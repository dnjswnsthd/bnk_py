# %% [markdown]
# <a href="https://colab.research.google.com/github/dnjswnsthd/bnk_py/blob/develop/python_workshop02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Workshop Tips Query<h1>
#
# # 목표
# 다양한 Indexer를 이용한 원하는 데이터 질의

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 데이터 로딩
# * 파일명 : tips.csv
# * 사용함수 : pd.read_csv()

# %%
url = 'https://www.dropbox.com/s/6hcpx66uwecoq0c/tips.csv?dl=1'
file = 'tips.csv'
import os
if os.name == 'posix':
  # !wget -O $file $url
else:
  # !pip install wget
  import wget
  wget.download(url, out=file)
# Out:
# --2022-09-15 03:31:24--  https://www.dropbox.com/s/6hcpx66uwecoq0c/tips.csv?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.85.18, 2620:100:6030:18::a27d:5012
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/6hcpx66uwecoq0c/tips.csv [following]
# --2022-09-15 03:31:25--  https://www.dropbox.com/s/dl/6hcpx66uwecoq0c/tips.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc91be775ce4026403cbca5125e4.dl.dropboxusercontent.com/cd/0/get/Bs-suYkOije7cGHC1ARzcdh7o7KN33zpawuIfwVO1RO30BFQRpo0P5yfe82JO-6XSIiGBeFJWU7tPvaHFxT56xrl9aRd5mexJ1X1L4Hw43hPJAadyBMOHEUHbt3jO5rJzuvcXjqcJ8NCDFJRT3lL4F8yA0FHbYt0aHwfXwmLV2rDZQ/file?dl=1# [following]
# ...

# %%
tips = pd.read_csv('tips.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Q. tip을 $5이상 지불한 행을 조회하고 tip금액이 높은 순으로 정렬하세요.

# %%
tips.query('tip >= 5').sort_values(by='tip', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4
# ...

# %%
tips[tips['tip'] >= 5].sort_values(by='tip', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4
# ...

# %% [markdown]
# ## Q. total_bill의 10% 이상을 tip으로 지불한 행을 조회하고 total_bill이 높은 순으로 10건만 표시하세요.

# %%
tips.query('tip >= total_bill * 0.1').sort_values('total_bill', ascending=False).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 112       38.07   4.00    Male     No   Sun  Dinner     3
# 238       35.83   4.67  Female     No   Sat  Dinner     3

# %%
tips[tips['tip'] >= (tips['total_bill']*0.1)].sort_values('total_bill', ascending=False).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 112       38.07   4.00    Male     No   Sun  Dinner     3
# 238       35.83   4.67  Female     No   Sat  Dinner     3

# %% [markdown]
# ## Q. total_bill을 $40이상 지불하고 tip을 total_bill의 10% 미만으로 지불한 행을 구하세요.

# %%
tips.query('total_bill >= 40 & tip < total_bill * 0.1')
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 102       44.30  2.5  Female    Yes  Sat  Dinner     3
# 182       45.35  3.5    Male    Yes  Sun  Dinner     3
# 184       40.55  3.0    Male    Yes  Sun  Dinner     2

# %%
tips[(tips ['total_bill'] > 40) & (tips['tip'] < tips['total_bill']*0.1)]
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 102       44.30  2.5  Female    Yes  Sat  Dinner     3
# 182       45.35  3.5    Male    Yes  Sun  Dinner     3
# 184       40.55  3.0    Male    Yes  Sun  Dinner     2

# %% [markdown]
# ## Q. tip을 $10 이상 지불한 남성(Male)이 있는 행을 구하세요.

# %%
tips.query('tip >= 10 & sex == "Male"')
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
tips[(tips['tip'] >= 10) & (tips['sex'] == 'Male')]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %% [markdown]
# ## Q. 주말(Sat, Sun) 저녁(Dinner)에 혼자인 행을 구하세요.

# %%
tips.query('day in ["Sat", "Sun"] & time == "Dinner" & size == 1')
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1
# 111        7.25  1.0  Female     No  Sat  Dinner     1

# %%
tips[((tips['day'] == 'Sat') | (tips['day'] == 'Sun')) & (tips['time'] == 'Dinner') & (tips['size'] == 1)]
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1
# 111        7.25  1.0  Female     No  Sat  Dinner     1

# %%
tips[(tips['day'].isin(['Sat', 'Sun'])) & (tips['time'] == 'Dinner') & (tips['size'] == 1)]
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1
# 111        7.25  1.0  Female     No  Sat  Dinner     1

# %% [markdown]
# ## Q. total_bill 과 tip의 평균을 구하세요.

# %%
tips[['total_bill', 'tip']].mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# dtype: float64

# %%
tips[['total_bill', 'tip']].agg(['mean']) #약간의 꼼수 agg는 원래 여러개 하려고하는거기때문
# Out:
#       total_bill       tip
# mean   19.785943  2.998279

# %%
tips.agg(['mean'])[['total_bill', 'tip']]
# Out:
#       total_bill       tip
# mean   19.785943  2.998279

# %% [markdown]
# ## Q. total_bill, tip, size의 최대 값과 최소 값을 구하세요.

# %%
tips[['total_bill', 'tip', 'size']].agg(['max', 'min'])
# Out:
#      total_bill   tip  size
# max       50.81  10.0     6
# min        3.07   1.0     1

# %% [markdown]
# ## Q. 여성(Female)과 남성(Male) 각각, 가장 total_bill을 많이 지불한 행을 조회하세요.

# %%
cond_f = tips['sex'] == 'Female'
cond_m = tips['sex'] == 'Male'

max_f = tips.loc[cond_f, 'total_bill'].max()
max_m = tips.loc[cond_m, 'total_bill'].max()

tips[(cond_f & (tips['total_bill'] == max_f)) |
     (cond_m & (tips['total_bill'] == max_m))]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 102       44.30   2.5  Female    Yes  Sat  Dinner     3
# 170       50.81  10.0    Male    Yes  Sat  Dinner     3

# %%
tips.query('(@cond_m & total_bill == @max_m) | (@cond_f & total_bill == @max_f)')
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 102       44.30   2.5  Female    Yes  Sat  Dinner     3
# 170       50.81  10.0    Male    Yes  Sat  Dinner     3

# %% [markdown]
# ## Q. 남성과 여성의 흡연자 수를 각각 구하세요.

# %%
tips.loc[tips['smoker'] == 'Yes', 'sex'].value_counts()
# Out:
# Male      60
# Female    33
# Name: sex, dtype: int64

# %% [markdown]
# ## Q. 주말(토,일요일) 저녁, 남성의 일행 수의 평균을 구하세요.

# %%
tips.loc[(tips['day'].isin(['Sat', 'Sun'])) & (tips['sex'] == 'Male'), 'size'].mean()
# Out:
# 2.7264957264957266
